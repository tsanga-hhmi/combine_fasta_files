# %%
from pathlib import Path
import shutil

fasta_files = [
    Path("/Users/tsanga/Documents/Arthur_GENIE_Work/RNA_AI/FASTA/RN2-ItoQ/Ribonanza-L-rna-002-010.fasta"),
    Path("/Users/tsanga/Documents/Arthur_GENIE_Work/RNA_AI/FASTA/RN2-ItoQ/Ribonanza-M-rna-003-002.fasta"),
    Path("/Users/tsanga/Documents/Arthur_GENIE_Work/RNA_AI/FASTA/RN2-ItoQ/Ribonanza-Q-rna-008-008.fasta"),
]

output_file = Path("Ribonanza-LMQ-001.fasta")

with output_file.open("wb") as out_f:
    for fp in fasta_files:
        with fp.open("rb") as in_f:
            shutil.copyfileobj(in_f, out_f, length=1024 * 1024)

print("Done.")
# Out:
# Done.
